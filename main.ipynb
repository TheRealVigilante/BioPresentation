# %% [markdown]
# # Extract and Plot

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

file_path = "pgc-mdd2025_no23andMe_div_v3-49-46-01.tsv.gz"

# ----------------------------------------------------
# 1. Define expected columns manually (based on PGC MDD GWAS schema)
# ----------------------------------------------------
column_names = [
    "CHR",        # Chromosome
    "BP",         # Base-pair position
    "SNP",        # rsID
    "A1",         # Effect allele
    "A2",         # Other allele
    "BETA",       # Effect size
    "SE",         # Standard error
    "PVAL",       # p-value
    "FRQ_A1",     # Frequency of A1 in cases
    "FRQ_U",      # Frequency in controls
    "INFO",       # Imputation info
    "N",          # Sample size or effective N
    "NMISS",      # Missing count
    "N_TOTAL",    # Total samples
    "QC",         # QC flag
    "GENPOS",     # Genetic position
    "RSQ"         # Imputation R² or similar
]

# Load with manual headers
df = pd.read_csv(
    file_path,
    sep='\t',
    compression='gzip',
    names=column_names,
    comment='#',
    header=None,
    low_memory=False
)

print(f"✅ Loaded {len(df):,} variants with proper headers.")
print(df.head())

# ----------------------------------------------------
# 2. Filter significant SNPs (p < 5e-8)
# ----------------------------------------------------
sig_threshold = 5e-8
significant_snps = df[df['PVAL'] < sig_threshold].copy()

print(f"\n🧬 Significant SNPs (p < {sig_threshold}): {len(significant_snps):,}")

# ----------------------------------------------------
# 3. (Optional) Manhattan plot
# ----------------------------------------------------
df['-log10(P)'] = -np.log10(df['PVAL'])
plt.figure(figsize=(12, 6))
sns.scatterplot(
    data=df.sample(min(500000, len(df))),  # sample for faster plotting
    x='BP',
    y='-log10(P)',
    hue='CHR',
    palette='tab20',
    s=5,
    linewidth=0
)
plt.axhline(-np.log10(sig_threshold), color='red', linestyle='--', label='Genome-wide significance')
plt.legend()
plt.title('Manhattan Plot - Depression GWAS (PGC MDD)')
plt.xlabel('Chromosome Position (BP)')
plt.ylabel('-log10(p-value)')
plt.tight_layout()
plt.show()

# ----------------------------------------------------
# 4. Save significant SNPs
# ----------------------------------------------------
significant_snps.to_csv("significant_snps_depression.tsv", sep='\t', index=False)
print("\n💾 Saved significant SNPs to 'significant_snps_depression.tsv'")

# %% [markdown]
# # Mapping SNPs to Genes

# %%
import pandas as pd
import requests
import time

# Load your SNP dataset
df = pd.read_csv("significant_snps_depression.tsv", sep='\t')
print(f"Loaded {len(df)} SNPs")

# Function to map SNP position to nearest gene via Ensembl
def get_nearest_gene(chr_num, bp):
    server = "https://rest.ensembl.org"
    ext = f"/overlap/region/human/{chr_num}:{bp}-{bp}?feature=gene"
    headers = {"Content-Type": "application/json"}
    try:
        r = requests.get(server + ext, headers=headers, timeout=10)
        if not r.ok:
            return None
        data = r.json()
        if len(data) == 0:
            return None
        # Get closest gene symbol
        nearest_gene = data[0].get('gene_id', None)
        gene_symbol = data[0].get('external_name', None)
        return gene_symbol
    except Exception:
        return None

# Map a subset first (you can scale up later)
results = []
for i, row in df.iterrows():  # try all snps
    gene = get_nearest_gene(row['CHR'], int(row['BP']))
    results.append({'SNP': row['SNP'], 'symbol': gene})
    if i % 10 == 0:
        print(f"Processed {i+1} SNPs...")
    time.sleep(0.3)

mapped = pd.DataFrame(results)
merged = df.merge(mapped, on='SNP', how='left')
merged.to_csv("depression_SNP_gene_positional.tsv", sep='\t', index=False)

print(f"✅ Saved mapped SNP-gene pairs: depression_SNP_gene_positional.tsv")
print(merged.head(10))
# Out:
# Loaded 13074 SNPs
# Processed 1 SNPs...
# Processed 11 SNPs...
# Processed 21 SNPs...
# Processed 31 SNPs...
# Processed 41 SNPs...
# Processed 51 SNPs...
# Processed 61 SNPs...
# Processed 71 SNPs...
# Processed 81 SNPs...
# Processed 91 SNPs...
# Processed 101 SNPs...
# Processed 111 SNPs...
# Processed 121 SNPs...
# Processed 131 SNPs...
# Processed 141 SNPs...
# Processed 151 SNPs...
# Processed 161 SNPs...
# Processed 171 SNPs...
# Processed 181 SNPs...
# Processed 191 SNPs...
# Processed 201 SNPs...
# Processed 211 SNPs...
# Processed 221 SNPs...
# Processed 231 SNPs...
# Processed 241 SNPs...
# Processed 251 SNPs...
# Processed 261 SNPs...
# Processed 271 SNPs...
# Processed 281 SNPs...
# Processed 291 SNPs...
# Processed 301 SNPs...
# Processed 311 SNPs...
# Processed 321 SNPs...
# Processed 331 SNPs...
# Processed 341 SNPs...
# Processed 351 SNPs...
# Processed 361 SNPs...
# Processed 371 SNPs...
# Processed 381 SNPs...
# Processed 391 SNPs...
# Processed 401 SNPs...
# Processed 411 SNPs...
# Processed 421 SNPs...
# Processed 431 SNPs...
# Processed 441 SNPs...
# Processed 451 SNPs...
# Processed 461 SNPs...
# Processed 471 SNPs...
# Processed 481 SNPs...
# Processed 491 SNPs...
# Processed 501 SNPs...
# Processed 511 SNPs...
# Processed 521 SNPs...
# Processed 531 SNPs...
# Processed 541 SNPs...
# Processed 551 SNPs...
# Processed 561 SNPs...
# Processed 571 SNPs...
# Processed 581 SNPs...
# Processed 591 SNPs...
# Processed 601 SNPs...
# Processed 611 SNPs...
# Processed 621 SNPs...
# Processed 631 SNPs...
# Processed 641 SNPs...
# Processed 651 SNPs...
# Processed 661 SNPs...
# Processed 671 SNPs...
# Processed 681 SNPs...
# Processed 691 SNPs...
# Processed 701 SNPs...
# Processed 711 SNPs...
# Processed 721 SNPs...
# Processed 731 SNPs...
# Processed 741 SNPs...
# Processed 751 SNPs...
# Processed 761 SNPs...
# Processed 771 SNPs...
# Processed 781 SNPs...
# Processed 791 SNPs...
# Processed 801 SNPs...
# Processed 811 SNPs...
# Processed 821 SNPs...
# Processed 831 SNPs...
# Processed 841 SNPs...
# Processed 851 SNPs...
# Processed 861 SNPs...
# Processed 871 SNPs...
# Processed 881 SNPs...
# Processed 891 SNPs...
# Processed 901 SNPs...
# Processed 911 SNPs...
# Processed 921 SNPs...
# Processed 931 SNPs...
# Processed 941 SNPs...
# Processed 951 SNPs...
# Processed 961 SNPs...
# Processed 971 SNPs...
# Processed 981 SNPs...
# Processed 991 SNPs...
# Processed 1001 SNPs...
# Processed 1011 SNPs...
# Processed 1021 SNPs...
# Processed 1031 SNPs...
# Processed 1041 SNPs...
# Processed 1051 SNPs...
# Processed 1061 SNPs...
# Processed 1071 SNPs...
# Processed 1081 SNPs...
# Processed 1091 SNPs...
# Processed 1101 SNPs...
# Processed 1111 SNPs...
# Processed 1121 SNPs...
# Processed 1131 SNPs...
# Processed 1141 SNPs...
# Processed 1151 SNPs...
# Processed 1161 SNPs...
# Processed 1171 SNPs...
# Processed 1181 SNPs...
# Processed 1191 SNPs...
# Processed 1201 SNPs...
# Processed 1211 SNPs...
# Processed 1221 SNPs...
# Processed 1231 SNPs...
# Processed 1241 SNPs...
# Processed 1251 SNPs...
# Processed 1261 SNPs...
# Processed 1271 SNPs...
# Processed 1281 SNPs...
# Processed 1291 SNPs...
# Processed 1301 SNPs...
# Processed 1311 SNPs...
# Processed 1321 SNPs...
# Processed 1331 SNPs...
# Processed 1341 SNPs...
# Processed 1351 SNPs...
# Processed 1361 SNPs...
# Processed 1371 SNPs...
# Processed 1381 SNPs...
# Processed 1391 SNPs...
# Processed 1401 SNPs...
# Processed 1411 SNPs...
# Processed 1421 SNPs...
# Processed 1431 SNPs...
# Processed 1441 SNPs...
# Processed 1451 SNPs...
# Processed 1461 SNPs...
# Processed 1471 SNPs...
# Processed 1481 SNPs...
# Processed 1491 SNPs...
# Processed 1501 SNPs...
# Processed 1511 SNPs...
# Processed 1521 SNPs...
# Processed 1531 SNPs...
# Processed 1541 SNPs...
# Processed 1551 SNPs...
# Processed 1561 SNPs...
# Processed 1571 SNPs...
# Processed 1581 SNPs...
# Processed 1591 SNPs...
# Processed 1601 SNPs...
# Processed 1611 SNPs...
# Processed 1621 SNPs...
# Processed 1631 SNPs...
# Processed 1641 SNPs...
# Processed 1651 SNPs...
# Processed 1661 SNPs...
# Processed 1671 SNPs...
# Processed 1681 SNPs...
# Processed 1691 SNPs...
# Processed 1701 SNPs...
# Processed 1711 SNPs...
# Processed 1721 SNPs...
# Processed 1731 SNPs...
# Processed 1741 SNPs...
# Processed 1751 SNPs...
# Processed 1761 SNPs...
# Processed 1771 SNPs...
# Processed 1781 SNPs...
# Processed 1791 SNPs...
# Processed 1801 SNPs...
# Processed 1811 SNPs...
# Processed 1821 SNPs...
# Processed 1831 SNPs...
# Processed 1841 SNPs...
# Processed 1851 SNPs...
# Processed 1861 SNPs...
# Processed 1871 SNPs...
# Processed 1881 SNPs...
# Processed 1891 SNPs...
# Processed 1901 SNPs...
# Processed 1911 SNPs...
# Processed 1921 SNPs...
# Processed 1931 SNPs...
# Processed 1941 SNPs...
# Processed 1951 SNPs...
# Processed 1961 SNPs...
# Processed 1971 SNPs...
# Processed 1981 SNPs...
# Processed 1991 SNPs...
# Processed 2001 SNPs...
# Processed 2011 SNPs...
# Processed 2021 SNPs...
# Processed 2031 SNPs...
# Processed 2041 SNPs...
# Processed 2051 SNPs...
# Processed 2061 SNPs...
# Processed 2071 SNPs...
# Processed 2081 SNPs...
# Processed 2091 SNPs...
# Processed 2101 SNPs...
# Processed 2111 SNPs...
# Processed 2121 SNPs...
# Processed 2131 SNPs...
# Processed 2141 SNPs...
# Processed 2151 SNPs...
# Processed 2161 SNPs...
# Processed 2171 SNPs...
# Processed 2181 SNPs...
# Processed 2191 SNPs...
# Processed 2201 SNPs...
# Processed 2211 SNPs...
# Processed 2221 SNPs...
# Processed 2231 SNPs...
# Processed 2241 SNPs...
# Processed 2251 SNPs...
# Processed 2261 SNPs...
# Processed 2271 SNPs...
# Processed 2281 SNPs...
# Processed 2291 SNPs...
# Processed 2301 SNPs...
# Processed 2311 SNPs...
# Processed 2321 SNPs...
# Processed 2331 SNPs...
# Processed 2341 SNPs...
# Processed 2351 SNPs...
# Processed 2361 SNPs...
# Processed 2371 SNPs...
# Processed 2381 SNPs...
# Processed 2391 SNPs...
# Processed 2401 SNPs...
# Processed 2411 SNPs...
# Processed 2421 SNPs...
# Processed 2431 SNPs...
# Processed 2441 SNPs...
# Processed 2451 SNPs...
# Processed 2461 SNPs...
# Processed 2471 SNPs...
# Processed 2481 SNPs...
# Processed 2491 SNPs...
# Processed 2501 SNPs...
# Processed 2511 SNPs...
# Processed 2521 SNPs...
# Processed 2531 SNPs...
# Processed 2541 SNPs...
# Processed 2551 SNPs...
# Processed 2561 SNPs...
# Processed 2571 SNPs...
# Processed 2581 SNPs...
# Processed 2591 SNPs...
# Processed 2601 SNPs...
# Processed 2611 SNPs...
# Processed 2621 SNPs...
# Processed 2631 SNPs...
# Processed 2641 SNPs...
# Processed 2651 SNPs...
# Processed 2661 SNPs...
# Processed 2671 SNPs...
# Processed 2681 SNPs...
# Processed 2691 SNPs...
# Processed 2701 SNPs...
# Processed 2711 SNPs...
# Processed 2721 SNPs...
# Processed 2731 SNPs...
# Processed 2741 SNPs...
# Processed 2751 SNPs...
# Processed 2761 SNPs...
# Processed 2771 SNPs...
# Processed 2781 SNPs...
# Processed 2791 SNPs...
# Processed 2801 SNPs...
# Processed 2811 SNPs...
# Processed 2821 SNPs...
# Processed 2831 SNPs...
# Processed 2841 SNPs...
# Processed 2851 SNPs...
# Processed 2861 SNPs...
# Processed 2871 SNPs...
# Processed 2881 SNPs...
# Processed 2891 SNPs...
# Processed 2901 SNPs...
# Processed 2911 SNPs...
# Processed 2921 SNPs...
# Processed 2931 SNPs...
# Processed 2941 SNPs...
# Processed 2951 SNPs...
# Processed 2961 SNPs...
# Processed 2971 SNPs...
# Processed 2981 SNPs...
# Processed 2991 SNPs...
# Processed 3001 SNPs...
# Processed 3011 SNPs...
# Processed 3021 SNPs...
# Processed 3031 SNPs...
# Processed 3041 SNPs...
# Processed 3051 SNPs...
# Processed 3061 SNPs...
# Processed 3071 SNPs...
# Processed 3081 SNPs...
# Processed 3091 SNPs...
# Processed 3101 SNPs...
# Processed 3111 SNPs...
# Processed 3121 SNPs...
# Processed 3131 SNPs...
# Processed 3141 SNPs...
# Processed 3151 SNPs...
# Processed 3161 SNPs...
# Processed 3171 SNPs...
# Processed 3181 SNPs...
# Processed 3191 SNPs...
# Processed 3201 SNPs...
# Processed 3211 SNPs...
# Processed 3221 SNPs...
# Processed 3231 SNPs...
# Processed 3241 SNPs...
# Processed 3251 SNPs...
# Processed 3261 SNPs...
# Processed 3271 SNPs...
# Processed 3281 SNPs...
# Processed 3291 SNPs...
# Processed 3301 SNPs...
# Processed 3311 SNPs...
# Processed 3321 SNPs...
# Processed 3331 SNPs...
# Processed 3341 SNPs...
# Processed 3351 SNPs...
# Processed 3361 SNPs...
# Processed 3371 SNPs...
# Processed 3381 SNPs...
# Processed 3391 SNPs...
# Processed 3401 SNPs...
# Processed 3411 SNPs...
# Processed 3421 SNPs...
# Processed 3431 SNPs...
# Processed 3441 SNPs...
# Processed 3451 SNPs...
# Processed 3461 SNPs...
# Processed 3471 SNPs...
# Processed 3481 SNPs...
# Processed 3491 SNPs...
# Processed 3501 SNPs...
# Processed 3511 SNPs...
# Processed 3521 SNPs...
# Processed 3531 SNPs...
# Processed 3541 SNPs...
# Processed 3551 SNPs...
# Processed 3561 SNPs...
# Processed 3571 SNPs...
# Processed 3581 SNPs...
# Processed 3591 SNPs...
# Processed 3601 SNPs...
# Processed 3611 SNPs...
# Processed 3621 SNPs...
# Processed 3631 SNPs...
# Processed 3641 SNPs...
# Processed 3651 SNPs...
# Processed 3661 SNPs...
# Processed 3671 SNPs...
# Processed 3681 SNPs...
# Processed 3691 SNPs...
# Processed 3701 SNPs...
# Processed 3711 SNPs...
# Processed 3721 SNPs...
# Processed 3731 SNPs...
# Processed 3741 SNPs...
# Processed 3751 SNPs...
# Processed 3761 SNPs...
# Processed 3771 SNPs...
# Processed 3781 SNPs...
# Processed 3791 SNPs...
# Processed 3801 SNPs...
# Processed 3811 SNPs...
# Processed 3821 SNPs...
# Processed 3831 SNPs...
# Processed 3841 SNPs...
# Processed 3851 SNPs...
# Processed 3861 SNPs...
# Processed 3871 SNPs...
# Processed 3881 SNPs...
# Processed 3891 SNPs...
# Processed 3901 SNPs...
# Processed 3911 SNPs...
# Processed 3921 SNPs...
# Processed 3931 SNPs...
# Processed 3941 SNPs...
# Processed 3951 SNPs...
# Processed 3961 SNPs...
# Processed 3971 SNPs...
# Processed 3981 SNPs...
# Processed 3991 SNPs...
# Processed 4001 SNPs...
# Processed 4011 SNPs...
# Processed 4021 SNPs...
# Processed 4031 SNPs...
# Processed 4041 SNPs...
# Processed 4051 SNPs...
# Processed 4061 SNPs...
# Processed 4071 SNPs...
# Processed 4081 SNPs...
# Processed 4091 SNPs...
# Processed 4101 SNPs...
# Processed 4111 SNPs...
# Processed 4121 SNPs...
# Processed 4131 SNPs...
# Processed 4141 SNPs...
# Processed 4151 SNPs...
# Processed 4161 SNPs...
# Processed 4171 SNPs...
# Processed 4181 SNPs...
# Processed 4191 SNPs...
# Processed 4201 SNPs...
# Processed 4211 SNPs...
# Processed 4221 SNPs...
# Processed 4231 SNPs...
# Processed 4241 SNPs...
# Processed 4251 SNPs...
# Processed 4261 SNPs...
# Processed 4271 SNPs...
# Processed 4281 SNPs...
# Processed 4291 SNPs...
# Processed 4301 SNPs...
# Processed 4311 SNPs...
# Processed 4321 SNPs...
# Processed 4331 SNPs...
# Processed 4341 SNPs...
# Processed 4351 SNPs...
# Processed 4361 SNPs...
# Processed 4371 SNPs...
# Processed 4381 SNPs...
# Processed 4391 SNPs...
# Processed 4401 SNPs...
# Processed 4411 SNPs...
# Processed 4421 SNPs...
# Processed 4431 SNPs...
# Processed 4441 SNPs...
# Processed 4451 SNPs...
# Processed 4461 SNPs...
# Processed 4471 SNPs...
# Processed 4481 SNPs...
# Processed 4491 SNPs...
# Processed 4501 SNPs...
# Processed 4511 SNPs...
# Processed 4521 SNPs...
# Processed 4531 SNPs...
# Processed 4541 SNPs...
# Processed 4551 SNPs...
# Processed 4561 SNPs...
# Processed 4571 SNPs...
# Processed 4581 SNPs...
# Processed 4591 SNPs...
# Processed 4601 SNPs...
# Processed 4611 SNPs...
# Processed 4621 SNPs...
# Processed 4631 SNPs...
# Processed 4641 SNPs...
# Processed 4651 SNPs...
# Processed 4661 SNPs...
# Processed 4671 SNPs...
# Processed 4681 SNPs...
# Processed 4691 SNPs...
# Processed 4701 SNPs...
# Processed 4711 SNPs...
# Processed 4721 SNPs...
# Processed 4731 SNPs...
# Processed 4741 SNPs...
# Processed 4751 SNPs...
# Processed 4761 SNPs...
# Processed 4771 SNPs...
# Processed 4781 SNPs...
# Processed 4791 SNPs...
# Processed 4801 SNPs...
# Processed 4811 SNPs...
# Processed 4821 SNPs...
# Processed 4831 SNPs...
# Processed 4841 SNPs...
# Processed 4851 SNPs...
# Processed 4861 SNPs...
# Processed 4871 SNPs...
# Processed 4881 SNPs...
# Processed 4891 SNPs...
# Processed 4901 SNPs...
# Processed 4911 SNPs...
# Processed 4921 SNPs...
# Processed 4931 SNPs...
# Processed 4941 SNPs...
# Processed 4951 SNPs...
# Processed 4961 SNPs...
# Processed 4971 SNPs...
# Processed 4981 SNPs...
# Processed 4991 SNPs...
# Processed 5001 SNPs...
# Processed 5011 SNPs...
# Processed 5021 SNPs...
# Processed 5031 SNPs...
# Processed 5041 SNPs...
# Processed 5051 SNPs...
# Processed 5061 SNPs...
# Processed 5071 SNPs...
# Processed 5081 SNPs...
# Processed 5091 SNPs...
# Processed 5101 SNPs...
# Processed 5111 SNPs...
# Processed 5121 SNPs...
# Processed 5131 SNPs...
# Processed 5141 SNPs...
# Processed 5151 SNPs...
# Processed 5161 SNPs...
# Processed 5171 SNPs...
# Processed 5181 SNPs...
# Processed 5191 SNPs...
# Processed 5201 SNPs...
# Processed 5211 SNPs...
# Processed 5221 SNPs...
# Processed 5231 SNPs...
# Processed 5241 SNPs...
# Processed 5251 SNPs...
# Processed 5261 SNPs...
# Processed 5271 SNPs...
# Processed 5281 SNPs...
# Processed 5291 SNPs...
# Processed 5301 SNPs...
# Processed 5311 SNPs...
# Processed 5321 SNPs...
# Processed 5331 SNPs...
# Processed 5341 SNPs...
# Processed 5351 SNPs...
# Processed 5361 SNPs...
# Processed 5371 SNPs...
# Processed 5381 SNPs...
# Processed 5391 SNPs...
# Processed 5401 SNPs...
# Processed 5411 SNPs...
# Processed 5421 SNPs...
# Processed 5431 SNPs...
# Processed 5441 SNPs...
# Processed 5451 SNPs...
# Processed 5461 SNPs...
# Processed 5471 SNPs...
# Processed 5481 SNPs...
# Processed 5491 SNPs...
# Processed 5501 SNPs...
# Processed 5511 SNPs...
# Processed 5521 SNPs...
# Processed 5531 SNPs...
# Processed 5541 SNPs...
# Processed 5551 SNPs...
# Processed 5561 SNPs...
# Processed 5571 SNPs...
# Processed 5581 SNPs...
# Processed 5591 SNPs...
# Processed 5601 SNPs...
# Processed 5611 SNPs...
# Processed 5621 SNPs...
# Processed 5631 SNPs...
# Processed 5641 SNPs...
# Processed 5651 SNPs...
# Processed 5661 SNPs...
# Processed 5671 SNPs...
# Processed 5681 SNPs...
# Processed 5691 SNPs...
# Processed 5701 SNPs...
# Processed 5711 SNPs...
# Processed 5721 SNPs...
# Processed 5731 SNPs...
# Processed 5741 SNPs...
# Processed 5751 SNPs...
# Processed 5761 SNPs...
# Processed 5771 SNPs...
# Processed 5781 SNPs...
# Processed 5791 SNPs...
# Processed 5801 SNPs...
# Processed 5811 SNPs...
# Processed 5821 SNPs...
# Processed 5831 SNPs...
# Processed 5841 SNPs...
# Processed 5851 SNPs...
# Processed 5861 SNPs...
# Processed 5871 SNPs...
# Processed 5881 SNPs...
# Processed 5891 SNPs...
# Processed 5901 SNPs...
# Processed 5911 SNPs...
# Processed 5921 SNPs...
# Processed 5931 SNPs...
# Processed 5941 SNPs...
# Processed 5951 SNPs...
# Processed 5961 SNPs...
# Processed 5971 SNPs...
# Processed 5981 SNPs...
# Processed 5991 SNPs...
# Processed 6001 SNPs...
# Processed 6011 SNPs...
# Processed 6021 SNPs...
# Processed 6031 SNPs...
# Processed 6041 SNPs...
# Processed 6051 SNPs...
# Processed 6061 SNPs...
# Processed 6071 SNPs...
# Processed 6081 SNPs...
# Processed 6091 SNPs...
# Processed 6101 SNPs...
# Processed 6111 SNPs...
# Processed 6121 SNPs...
# Processed 6131 SNPs...
# Processed 6141 SNPs...
# Processed 6151 SNPs...
# Processed 6161 SNPs...
# Processed 6171 SNPs...
# Processed 6181 SNPs...
# Processed 6191 SNPs...
# Processed 6201 SNPs...
# Processed 6211 SNPs...
# Processed 6221 SNPs...
# Processed 6231 SNPs...
# Processed 6241 SNPs...
# Processed 6251 SNPs...
# Processed 6261 SNPs...
# Processed 6271 SNPs...
# Processed 6281 SNPs...
# Processed 6291 SNPs...
# Processed 6301 SNPs...
# Processed 6311 SNPs...
# Processed 6321 SNPs...
# Processed 6331 SNPs...
# Processed 6341 SNPs...
# Processed 6351 SNPs...
# Processed 6361 SNPs...
# Processed 6371 SNPs...
# Processed 6381 SNPs...
# Processed 6391 SNPs...
# Processed 6401 SNPs...
# Processed 6411 SNPs...
# Processed 6421 SNPs...
# Processed 6431 SNPs...
# Processed 6441 SNPs...
# Processed 6451 SNPs...
# Processed 6461 SNPs...
# Processed 6471 SNPs...
# Processed 6481 SNPs...
# Processed 6491 SNPs...
# Processed 6501 SNPs...
# Processed 6511 SNPs...
# Processed 6521 SNPs...
# Processed 6531 SNPs...
# Processed 6541 SNPs...
# Processed 6551 SNPs...
# Processed 6561 SNPs...
# Processed 6571 SNPs...
# Processed 6581 SNPs...
# Processed 6591 SNPs...
# Processed 6601 SNPs...
# Processed 6611 SNPs...
# Processed 6621 SNPs...
# Processed 6631 SNPs...
# Processed 6641 SNPs...
# Processed 6651 SNPs...
# Processed 6661 SNPs...
# Processed 6671 SNPs...
# Processed 6681 SNPs...
# Processed 6691 SNPs...
# Processed 6701 SNPs...
# Processed 6711 SNPs...
# Processed 6721 SNPs...
# Processed 6731 SNPs...
# Processed 6741 SNPs...
# Processed 6751 SNPs...
# Processed 6761 SNPs...
# Processed 6771 SNPs...
# Processed 6781 SNPs...
# Processed 6791 SNPs...
# Processed 6801 SNPs...
# Processed 6811 SNPs...
# Processed 6821 SNPs...
# Processed 6831 SNPs...
# Processed 6841 SNPs...
# Processed 6851 SNPs...
# Processed 6861 SNPs...
# Processed 6871 SNPs...
# Processed 6881 SNPs...
# Processed 6891 SNPs...
# Processed 6901 SNPs...
# Processed 6911 SNPs...
# Processed 6921 SNPs...
# Processed 6931 SNPs...
# Processed 6941 SNPs...
# Processed 6951 SNPs...
# Processed 6961 SNPs...
# Processed 6971 SNPs...
# Processed 6981 SNPs...
# Processed 6991 SNPs...
# Processed 7001 SNPs...
# Processed 7011 SNPs...
# Processed 7021 SNPs...
# Processed 7031 SNPs...
# Processed 7041 SNPs...
# Processed 7051 SNPs...
# Processed 7061 SNPs...
# Processed 7071 SNPs...
# Processed 7081 SNPs...
# Processed 7091 SNPs...
# Processed 7101 SNPs...
# Processed 7111 SNPs...
# Processed 7121 SNPs...
# Processed 7131 SNPs...
# Processed 7141 SNPs...
# Processed 7151 SNPs...
# Processed 7161 SNPs...
# Processed 7171 SNPs...
# Processed 7181 SNPs...
# Processed 7191 SNPs...
# Processed 7201 SNPs...
# Processed 7211 SNPs...
# Processed 7221 SNPs...
# Processed 7231 SNPs...
# Processed 7241 SNPs...
# Processed 7251 SNPs...
# Processed 7261 SNPs...
# Processed 7271 SNPs...
# Processed 7281 SNPs...
# Processed 7291 SNPs...
# Processed 7301 SNPs...
# Processed 7311 SNPs...
# Processed 7321 SNPs...
# Processed 7331 SNPs...
# Processed 7341 SNPs...
# Processed 7351 SNPs...
# Processed 7361 SNPs...
# Processed 7371 SNPs...
# Processed 7381 SNPs...
# Processed 7391 SNPs...
# Processed 7401 SNPs...
# Processed 7411 SNPs...
# Processed 7421 SNPs...
# Processed 7431 SNPs...
# Processed 7441 SNPs...
# Processed 7451 SNPs...
# Processed 7461 SNPs...
# Processed 7471 SNPs...
# Processed 7481 SNPs...
# Processed 7491 SNPs...
# Processed 7501 SNPs...
# Processed 7511 SNPs...
# Processed 7521 SNPs...
# Processed 7531 SNPs...
# Processed 7541 SNPs...
# Processed 7551 SNPs...
# Processed 7561 SNPs...
# Processed 7571 SNPs...
# Processed 7581 SNPs...
# Processed 7591 SNPs...
# Processed 7601 SNPs...
# Processed 7611 SNPs...
# Processed 7621 SNPs...
# Processed 7631 SNPs...
# Processed 7641 SNPs...
# Processed 7651 SNPs...
# Processed 7661 SNPs...
# Processed 7671 SNPs...
# Processed 7681 SNPs...
# Processed 7691 SNPs...
# Processed 7701 SNPs...
# Processed 7711 SNPs...
# Processed 7721 SNPs...
# Processed 7731 SNPs...
# Processed 7741 SNPs...
# Processed 7751 SNPs...
# Processed 7761 SNPs...
# Processed 7771 SNPs...
# Processed 7781 SNPs...
# Processed 7791 SNPs...
# Processed 7801 SNPs...
# Processed 7811 SNPs...
# Processed 7821 SNPs...
# Processed 7831 SNPs...
# Processed 7841 SNPs...
# Processed 7851 SNPs...
# Processed 7861 SNPs...
# Processed 7871 SNPs...
# Processed 7881 SNPs...
# Processed 7891 SNPs...
# Processed 7901 SNPs...
# Processed 7911 SNPs...
# Processed 7921 SNPs...
# Processed 7931 SNPs...
# Processed 7941 SNPs...
# Processed 7951 SNPs...
# Processed 7961 SNPs...
# Processed 7971 SNPs...
# Processed 7981 SNPs...
# Processed 7991 SNPs...
# Processed 8001 SNPs...
# Processed 8011 SNPs...
# Processed 8021 SNPs...
# Processed 8031 SNPs...
# Processed 8041 SNPs...
# Processed 8051 SNPs...
# Processed 8061 SNPs...
# Processed 8071 SNPs...
# Processed 8081 SNPs...
# Processed 8091 SNPs...
# Processed 8101 SNPs...
# Processed 8111 SNPs...
# Processed 8121 SNPs...
# Processed 8131 SNPs...
# Processed 8141 SNPs...
# Processed 8151 SNPs...
# Processed 8161 SNPs...
# Processed 8171 SNPs...
# Processed 8181 SNPs...
# Processed 8191 SNPs...
# Processed 8201 SNPs...
# Processed 8211 SNPs...
# Processed 8221 SNPs...
# Processed 8231 SNPs...
# Processed 8241 SNPs...
# Processed 8251 SNPs...
# Processed 8261 SNPs...
# Processed 8271 SNPs...
# Processed 8281 SNPs...
# Processed 8291 SNPs...
# Processed 8301 SNPs...
# Processed 8311 SNPs...
# Processed 8321 SNPs...
# Processed 8331 SNPs...
# Processed 8341 SNPs...
# Processed 8351 SNPs...
# Processed 8361 SNPs...
# Processed 8371 SNPs...
# Processed 8381 SNPs...
# Processed 8391 SNPs...
# Processed 8401 SNPs...
# Processed 8411 SNPs...
# Processed 8421 SNPs...
# Processed 8431 SNPs...
# Processed 8441 SNPs...
# Processed 8451 SNPs...
# Processed 8461 SNPs...
# Processed 8471 SNPs...
# Processed 8481 SNPs...
# Processed 8491 SNPs...
# Processed 8501 SNPs...
# Processed 8511 SNPs...
# Processed 8521 SNPs...
# Processed 8531 SNPs...
# Processed 8541 SNPs...
# Processed 8551 SNPs...
# Processed 8561 SNPs...
# Processed 8571 SNPs...
# Processed 8581 SNPs...
# Processed 8591 SNPs...
# Processed 8601 SNPs...
# Processed 8611 SNPs...
# Processed 8621 SNPs...
# Processed 8631 SNPs...
# Processed 8641 SNPs...
# Processed 8651 SNPs...
# Processed 8661 SNPs...
# Processed 8671 SNPs...
# Processed 8681 SNPs...
# Processed 8691 SNPs...
# Processed 8701 SNPs...
# Processed 8711 SNPs...
# Processed 8721 SNPs...
# Processed 8731 SNPs...
# Processed 8741 SNPs...
# Processed 8751 SNPs...
# Processed 8761 SNPs...
# Processed 8771 SNPs...
# Processed 8781 SNPs...
# Processed 8791 SNPs...
# Processed 8801 SNPs...
# Processed 8811 SNPs...
# Processed 8821 SNPs...
# Processed 8831 SNPs...
# Processed 8841 SNPs...
# Processed 8851 SNPs...
# Processed 8861 SNPs...
# Processed 8871 SNPs...
# Processed 8881 SNPs...
# Processed 8891 SNPs...
# Processed 8901 SNPs...
# Processed 8911 SNPs...
# Processed 8921 SNPs...
# Processed 8931 SNPs...
# Processed 8941 SNPs...
# Processed 8951 SNPs...
# Processed 8961 SNPs...
# Processed 8971 SNPs...
# Processed 8981 SNPs...
# Processed 8991 SNPs...
# Processed 9001 SNPs...
# Processed 9011 SNPs...
# Processed 9021 SNPs...
# Processed 9031 SNPs...
# Processed 9041 SNPs...
# Processed 9051 SNPs...
# Processed 9061 SNPs...
# Processed 9071 SNPs...
# Processed 9081 SNPs...
# Processed 9091 SNPs...
# Processed 9101 SNPs...
# Processed 9111 SNPs...
# Processed 9121 SNPs...
# Processed 9131 SNPs...
# Processed 9141 SNPs...
# Processed 9151 SNPs...
# Processed 9161 SNPs...
# Processed 9171 SNPs...
# Processed 9181 SNPs...
# Processed 9191 SNPs...
# Processed 9201 SNPs...
# Processed 9211 SNPs...
# Processed 9221 SNPs...
# Processed 9231 SNPs...
# Processed 9241 SNPs...
# Processed 9251 SNPs...
# Processed 9261 SNPs...
# Processed 9271 SNPs...
# Processed 9281 SNPs...
# Processed 9291 SNPs...
# Processed 9301 SNPs...
# Processed 9311 SNPs...
# Processed 9321 SNPs...
# Processed 9331 SNPs...
# Processed 9341 SNPs...
# Processed 9351 SNPs...
# Processed 9361 SNPs...
# Processed 9371 SNPs...
# Processed 9381 SNPs...
# Processed 9391 SNPs...
# Processed 9401 SNPs...
# Processed 9411 SNPs...
# Processed 9421 SNPs...
# Processed 9431 SNPs...
# Processed 9441 SNPs...
# Processed 9451 SNPs...
# Processed 9461 SNPs...
# Processed 9471 SNPs...
# Processed 9481 SNPs...
# Processed 9491 SNPs...
# Processed 9501 SNPs...
# Processed 9511 SNPs...
# Processed 9521 SNPs...
# Processed 9531 SNPs...
# Processed 9541 SNPs...
# Processed 9551 SNPs...
# Processed 9561 SNPs...
# Processed 9571 SNPs...
# Processed 9581 SNPs...
# Processed 9591 SNPs...
# Processed 9601 SNPs...
# Processed 9611 SNPs...
# Processed 9621 SNPs...
# Processed 9631 SNPs...
# Processed 9641 SNPs...
# Processed 9651 SNPs...
# Processed 9661 SNPs...
# Processed 9671 SNPs...
# Processed 9681 SNPs...
# Processed 9691 SNPs...
# Processed 9701 SNPs...
# Processed 9711 SNPs...
# Processed 9721 SNPs...
# Processed 9731 SNPs...
# Processed 9741 SNPs...
# Processed 9751 SNPs...
# Processed 9761 SNPs...
# Processed 9771 SNPs...
# Processed 9781 SNPs...
# Processed 9791 SNPs...
# Processed 9801 SNPs...
# Processed 9811 SNPs...
# Processed 9821 SNPs...
# Processed 9831 SNPs...
# Processed 9841 SNPs...
# Processed 9851 SNPs...
# Processed 9861 SNPs...
# Processed 9871 SNPs...
# Processed 9881 SNPs...
# Processed 9891 SNPs...
# Processed 9901 SNPs...
# Processed 9911 SNPs...
# Processed 9921 SNPs...
# Processed 9931 SNPs...
# Processed 9941 SNPs...
# Processed 9951 SNPs...
# Processed 9961 SNPs...
# Processed 9971 SNPs...
# Processed 9981 SNPs...
# Processed 9991 SNPs...
# Processed 10001 SNPs...
# Processed 10011 SNPs...
# Processed 10021 SNPs...
# Processed 10031 SNPs...
# Processed 10041 SNPs...
# Processed 10051 SNPs...
# Processed 10061 SNPs...
# Processed 10071 SNPs...
# Processed 10081 SNPs...
# Processed 10091 SNPs...
# Processed 10101 SNPs...
# Processed 10111 SNPs...
# Processed 10121 SNPs...
# Processed 10131 SNPs...
# Processed 10141 SNPs...
# Processed 10151 SNPs...
# Processed 10161 SNPs...
# Processed 10171 SNPs...
# Processed 10181 SNPs...
# Processed 10191 SNPs...
# Processed 10201 SNPs...
# Processed 10211 SNPs...
# Processed 10221 SNPs...
# Processed 10231 SNPs...
# Processed 10241 SNPs...
# Processed 10251 SNPs...
# Processed 10261 SNPs...
# Processed 10271 SNPs...
# Processed 10281 SNPs...
# Processed 10291 SNPs...
# Processed 10301 SNPs...
# Processed 10311 SNPs...
# Processed 10321 SNPs...
# Processed 10331 SNPs...
# Processed 10341 SNPs...
# Processed 10351 SNPs...
# Processed 10361 SNPs...
# Processed 10371 SNPs...
# Processed 10381 SNPs...
# Processed 10391 SNPs...
# Processed 10401 SNPs...
# Processed 10411 SNPs...
# Processed 10421 SNPs...
# Processed 10431 SNPs...
# Processed 10441 SNPs...
# Processed 10451 SNPs...
# Processed 10461 SNPs...
# Processed 10471 SNPs...
# Processed 10481 SNPs...
# Processed 10491 SNPs...
# Processed 10501 SNPs...
# Processed 10511 SNPs...
# Processed 10521 SNPs...
# Processed 10531 SNPs...
# Processed 10541 SNPs...
# Processed 10551 SNPs...
# Processed 10561 SNPs...
# Processed 10571 SNPs...
# Processed 10581 SNPs...
# Processed 10591 SNPs...
# Processed 10601 SNPs...
# Processed 10611 SNPs...
# Processed 10621 SNPs...
# Processed 10631 SNPs...
# Processed 10641 SNPs...
# Processed 10651 SNPs...
# Processed 10661 SNPs...
# Processed 10671 SNPs...
# Processed 10681 SNPs...
# Processed 10691 SNPs...
# Processed 10701 SNPs...
# Processed 10711 SNPs...
# Processed 10721 SNPs...
# Processed 10731 SNPs...
# Processed 10741 SNPs...
# Processed 10751 SNPs...
# Processed 10761 SNPs...
# Processed 10771 SNPs...
# Processed 10781 SNPs...
# Processed 10791 SNPs...
# Processed 10801 SNPs...
# Processed 10811 SNPs...
# Processed 10821 SNPs...
# Processed 10831 SNPs...
# Processed 10841 SNPs...
# Processed 10851 SNPs...
# Processed 10861 SNPs...
# Processed 10871 SNPs...
# Processed 10881 SNPs...
# Processed 10891 SNPs...
# Processed 10901 SNPs...
# Processed 10911 SNPs...
# Processed 10921 SNPs...
# Processed 10931 SNPs...
# Processed 10941 SNPs...
# Processed 10951 SNPs...
# Processed 10961 SNPs...
# Processed 10971 SNPs...
# Processed 10981 SNPs...
# Processed 10991 SNPs...
# Processed 11001 SNPs...
# Processed 11011 SNPs...
# Processed 11021 SNPs...
# Processed 11031 SNPs...
# Processed 11041 SNPs...
# Processed 11051 SNPs...
# Processed 11061 SNPs...
# Processed 11071 SNPs...
# Processed 11081 SNPs...
# Processed 11091 SNPs...
# Processed 11101 SNPs...
# Processed 11111 SNPs...
# Processed 11121 SNPs...
# Processed 11131 SNPs...
# Processed 11141 SNPs...
# Processed 11151 SNPs...
# Processed 11161 SNPs...
# Processed 11171 SNPs...
# Processed 11181 SNPs...
# Processed 11191 SNPs...
# Processed 11201 SNPs...
# Processed 11211 SNPs...
# Processed 11221 SNPs...
# Processed 11231 SNPs...
# Processed 11241 SNPs...
# Processed 11251 SNPs...
# Processed 11261 SNPs...
# Processed 11271 SNPs...
# Processed 11281 SNPs...
# Processed 11291 SNPs...
# Processed 11301 SNPs...
# Processed 11311 SNPs...
# Processed 11321 SNPs...
# Processed 11331 SNPs...
# Processed 11341 SNPs...
# Processed 11351 SNPs...
# Processed 11361 SNPs...
# Processed 11371 SNPs...
# Processed 11381 SNPs...
# Processed 11391 SNPs...
# Processed 11401 SNPs...
# Processed 11411 SNPs...
# Processed 11421 SNPs...
# Processed 11431 SNPs...
# Processed 11441 SNPs...
# Processed 11451 SNPs...
# Processed 11461 SNPs...
# Processed 11471 SNPs...
# Processed 11481 SNPs...
# Processed 11491 SNPs...
# Processed 11501 SNPs...
# Processed 11511 SNPs...
# Processed 11521 SNPs...
# Processed 11531 SNPs...
# Processed 11541 SNPs...
# Processed 11551 SNPs...
# Processed 11561 SNPs...
# Processed 11571 SNPs...
# Processed 11581 SNPs...
# Processed 11591 SNPs...
# Processed 11601 SNPs...
# Processed 11611 SNPs...
# Processed 11621 SNPs...
# Processed 11631 SNPs...
# Processed 11641 SNPs...
# Processed 11651 SNPs...
# Processed 11661 SNPs...
# Processed 11671 SNPs...
# Processed 11681 SNPs...
# Processed 11691 SNPs...
# Processed 11701 SNPs...
# Processed 11711 SNPs...
# Processed 11721 SNPs...
# Processed 11731 SNPs...
# Processed 11741 SNPs...
# Processed 11751 SNPs...
# Processed 11761 SNPs...
# Processed 11771 SNPs...
# Processed 11781 SNPs...
# Processed 11791 SNPs...
# Processed 11801 SNPs...
# Processed 11811 SNPs...
# Processed 11821 SNPs...
# Processed 11831 SNPs...
# Processed 11841 SNPs...
# Processed 11851 SNPs...
# Processed 11861 SNPs...
# Processed 11871 SNPs...
# Processed 11881 SNPs...
# Processed 11891 SNPs...
# Processed 11901 SNPs...
# Processed 11911 SNPs...
# Processed 11921 SNPs...
# Processed 11931 SNPs...
# Processed 11941 SNPs...
# Processed 11951 SNPs...
# Processed 11961 SNPs...
# Processed 11971 SNPs...
# Processed 11981 SNPs...
# Processed 11991 SNPs...
# Processed 12001 SNPs...
# Processed 12011 SNPs...
# Processed 12021 SNPs...
# Processed 12031 SNPs...
# Processed 12041 SNPs...
# Processed 12051 SNPs...
# Processed 12061 SNPs...
# Processed 12071 SNPs...
# Processed 12081 SNPs...
# Processed 12091 SNPs...
# Processed 12101 SNPs...
# Processed 12111 SNPs...
# Processed 12121 SNPs...
# Processed 12131 SNPs...
# Processed 12141 SNPs...
# Processed 12151 SNPs...
# Processed 12161 SNPs...
# Processed 12171 SNPs...
# Processed 12181 SNPs...
# Processed 12191 SNPs...
# Processed 12201 SNPs...
# Processed 12211 SNPs...
# Processed 12221 SNPs...
# Processed 12231 SNPs...
# Processed 12241 SNPs...
# Processed 12251 SNPs...
# Processed 12261 SNPs...
# Processed 12271 SNPs...
# Processed 12281 SNPs...
# Processed 12291 SNPs...
# Processed 12301 SNPs...
# Processed 12311 SNPs...
# Processed 12321 SNPs...
# Processed 12331 SNPs...
# Processed 12341 SNPs...
# Processed 12351 SNPs...
# Processed 12361 SNPs...
# Processed 12371 SNPs...
# Processed 12381 SNPs...
# Processed 12391 SNPs...
# Processed 12401 SNPs...
# Processed 12411 SNPs...
# Processed 12421 SNPs...
# Processed 12431 SNPs...
# Processed 12441 SNPs...
# Processed 12451 SNPs...
# Processed 12461 SNPs...
# Processed 12471 SNPs...
# Processed 12481 SNPs...
# Processed 12491 SNPs...
# Processed 12501 SNPs...
# Processed 12511 SNPs...
# Processed 12521 SNPs...
# Processed 12531 SNPs...
# Processed 12541 SNPs...
# Processed 12551 SNPs...
# Processed 12561 SNPs...
# Processed 12571 SNPs...
# Processed 12581 SNPs...
# Processed 12591 SNPs...
# Processed 12601 SNPs...
# Processed 12611 SNPs...
# Processed 12621 SNPs...
# Processed 12631 SNPs...
# Processed 12641 SNPs...
# Processed 12651 SNPs...
# Processed 12661 SNPs...
# Processed 12671 SNPs...
# Processed 12681 SNPs...
# Processed 12691 SNPs...
# Processed 12701 SNPs...
# Processed 12711 SNPs...
# Processed 12721 SNPs...
# Processed 12731 SNPs...
# Processed 12741 SNPs...
# Processed 12751 SNPs...
# Processed 12761 SNPs...
# Processed 12771 SNPs...
# Processed 12781 SNPs...
# Processed 12791 SNPs...
# Processed 12801 SNPs...
# Processed 12811 SNPs...
# Processed 12821 SNPs...
# Processed 12831 SNPs...
# Processed 12841 SNPs...
# Processed 12851 SNPs...
# Processed 12861 SNPs...
# Processed 12871 SNPs...
# Processed 12881 SNPs...
# Processed 12891 SNPs...
# Processed 12901 SNPs...
# Processed 12911 SNPs...
# Processed 12921 SNPs...
# Processed 12931 SNPs...
# Processed 12941 SNPs...
# Processed 12951 SNPs...
# Processed 12961 SNPs...
# Processed 12971 SNPs...
# Processed 12981 SNPs...
# Processed 12991 SNPs...
# Processed 13001 SNPs...
# Processed 13011 SNPs...
# Processed 13021 SNPs...
# Processed 13031 SNPs...
# Processed 13041 SNPs...
# Processed 13051 SNPs...
# Processed 13061 SNPs...
# Processed 13071 SNPs...
# ✅ Saved mapped SNP-gene pairs: depression_SNP_gene_positional.tsv
#    CHR       BP        SNP A1 A2      BETA      SE          PVAL  FRQ_A1  \
# 0    1  8431607  rs3795310  T  C  0.016405  0.0027  1.822000e-09   0.444
# 1    1  8445360  rs3765971  C  T -0.015804  0.0028  1.992000e-08   0.329
# 2    1  8447404  rs2708630  C  T -0.016099  0.0028  1.282000e-08   0.324
# 3    1  8447722  rs2120461  C  T -0.016099  0.0028  1.132000e-08   0.327
# 4    1  8452725  rs2661863  T  C -0.015896  0.0028  2.002000e-08   0.321
# 5    1  8463176  rs2784737  T  C -0.015896  0.0028  2.173000e-08   0.322
# 6    1  8464509  rs2708632  T  C -0.015804  0.0028  2.822000e-08   0.321
# 7    1  8466730   rs301796  C  T -0.015896  0.0028  2.197000e-08   0.317
# 8    1  8467353   rs301795  A  G -0.015804  0.0028  2.576000e-08   0.317
# 9    1  8468278   rs301792  G  A -0.015804  0.0028  2.127000e-08   0.319
#
#    FRQ_U   INFO           N   NMISS  N_TOTAL    QC  GENPOS     RSQ    symbol
# 0  0.433  0.993  1251221.08  444445  1931220  12.5      26  0.2801  RERE-AS1
# 1  0.327  0.994  1281103.20  454276  1963209   0.0      27  0.4936      RERE
# 2  0.318  0.994  1281103.20  454276  1963209   5.3      27  0.3851      RERE
# 3  0.324  0.994  1281103.20  454276  1963209   2.2      27  0.4321      RERE
# 4  0.315  0.994  1281103.20  454276  1963209   6.4      27  0.3678      RERE
# 5  0.315  0.994  1281103.20  454276  1963209   6.1      27  0.3724      RERE
# 6  0.314  0.994  1271011.54  451269  1926959   0.3      22  0.4559      RERE
# 7  0.313  0.998  1279856.84  453916  1960892   7.8      27  0.3467      RERE
# 8  0.313  0.998  1279856.84  453916  1960892   8.5      27  0.3370      RERE
# 9  0.317  0.998  1279856.84  453916  1960892   4.3      27  0.3995      RERE

# %% [markdown]
# # Gene Enrichment

# %%
import pandas as pd
from gprofiler import GProfiler

# Load mapped SNP-gene file
df = pd.read_csv("depression_SNP_gene_positional.tsv", sep='\t')

# Filter non-null genes
gene_list = df['symbol'].dropna().unique().tolist()
print(f"Unique genes mapped: {len(gene_list)}")

# Initialize GProfiler
gp = GProfiler(return_dataframe=True)
results = gp.profile(
    organism='hsapiens',
    query=gene_list,
    sources=['GO:BP', 'GO:MF', 'KEGG']
)

# Save full results
results.to_csv("depression_pathway_enrichment.csv", index=False)
print("✅ Enrichment results saved as depression_pathway_enrichment.csv")

# Show top pathways
print(results[['native', 'name', 'p_value', 'intersection_size']].head(10))
# Out:
# Unique genes mapped: 456
# ✅ Enrichment results saved as depression_pathway_enrichment.csv
#        native                                name   p_value  intersection_size
# 0  GO:0007399          nervous system development  0.000086                 74
# 1  GO:0007417  central nervous system development  0.000570                 39
# 2  GO:0048731                  system development  0.003246                 96
# 3  GO:0035608             protein deglutamylation  0.003722                  4
# 4  GO:0007275  multicellular organism development  0.005399                107
# 5  GO:0048699               generation of neurons  0.005910                 47
# 6  GO:0022008                        neurogenesis  0.011905                 51
# 7  GO:0030182              neuron differentiation  0.016101                 44
# 8  GO:0048856    anatomical structure development  0.021340                126
# 9  GO:0007420                   brain development  0.025632                 28
